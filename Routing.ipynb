# %%
import googlemaps
import pandas as pd 
import numpy as np
import itertools 

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
gmaps = googlemaps.Client(key='AIzaSyDtQ8oPYrA3JtXLmk6MmPl7IKeOoD0YT_E')

# Geocoding an address
# geocode_result = gmaps.('1600 Amphitheatre Parkway, Mountain View, CA')

# %%
d = gmaps.distance_matrix([[41.7906903049399, -87.645033364855]],[[41.9578321488877,-87.8472168685989]], mode='transit')

# %%
census_tracts = pd.read_csv("chicago_census_tracts.csv")

# %%
origins = census_tracts[['lat','lon']].as_matrix()

# %%
destinations =[ [41.9268032, -87.6353216]]
d = gmaps.distance_matrix(origins[0:70],destinations, mode='transit')

# %%
batches = np.reshape(origins[:800], (16,50,2))

# %%
def extract_times(rows):
    return [  0 if row['elements'][0]['status']=='ZERO_RESULTS' else row['elements'][0]['duration']['value'] for row in rows]

# %%
times  = [ ]
for index, batch in enumerate(batches):
    print 'doing %i of %i ' %(index,len(batches))
    d = gmaps.distance_matrix(batch,destinations, mode='transit')
    try: 
        times += extract_times(d['rows'])
    except:
        print (d)

times
# Out:
# doing 0 of 16
# doing 1 of 16
# doing 2 of 16
# doing 3 of 16
# doing 4 of 16
# doing 5 of 16
# doing 6 of 16
# doing 7 of 16
# doing 8 of 16
# doing 9 of 16
# doing 10 of 16
# doing 11 of 16
# doing 12 of 16
# doing 13 of 16
# doing 14 of 16
# doing 15 of 16
# [4538,
#  3991,
#  5981,
#  3877,
#  4735,
#  5278,
#  4117,
#  3783,
#  3031,
#  1832,
#  2809,
#  482,
#  5388,
#  3555,
#  2609,
#  1116,
#  3944,
#  3016,
#  3358,
#  2561,
#  1366,
#  3123,
#  4926,
#  3621,
#  4036,
#  4860,
#  2317,
#  1507,
#  4262,
#  5096,
#  3989,
#  4465,
#  3715,
#  4741,
#  2810,
#  3401,
#  4544,
#  4503,
#  4635,
#  4023,
#  2888,
#  3679,
#  5443,
#  2712,
#  3633,
#  4139,
#  3809,
#  4816,
#  4344,
#  4368,
#  4545,
#  3471,
#  4702,
#  5201,
#  3663,
#  3881,
#  5097,
#  2695,
#  4892,
#  2432,
#  2456,
#  1596,
#  4043,
#  2035,
#  4167,
#  2207,
#  3804,
#  3624,
#  1646,
#  1705,
#  1295,
#  1591,
#  2855,
#  4057,
#  938,
#  4659,
#  3363,
#  3800,
#  3193,
#  5712,
#  4498,
#  777,
# ...

# %%
out  = census_tracts[0:800].join(pd.Series(times , name='times') )
out.to_csv("travel_times_peggy.csv")

# %%
census_tracts
# Out:
#            lon        lat      geoid10
# 0   -87.645033  41.790690  17031834700
# 1   -87.725891  41.964647  17031140601
# 2   -87.847217  41.957832  17031760802
# 3   -87.594268  41.801668  17031410200
# 4   -87.661106  41.754049  17031710300
# 5   -87.740577  41.804009  17031560400
# 6   -87.903895  41.980267  17031980000
# 7   -87.623768  41.813806  17031380700
# 8   -87.694415  41.986808  17031020801
# 9   -87.652366  41.963633  17031031502
# 10  -87.654695  41.995380  17031030103
# 11  -87.642605  41.926811  17031070103
# 12  -87.603746  41.797827  17031410500
# 13  -87.683342  41.855562  17031841200
# 14  -87.654936  41.988886  17031030601
# 15  -87.630901  41.905860  17031080202
# 16  -87.770533  41.920229  17031191302
# 17  -87.703690  41.986892  17031020701
# 18  -87.680650  41.877364  17031838000
# 19  -87.651605  41.980235  17031030706
# 20  -87.649886  41.904934  17031842200
# 21  -87.723170  41.969206  17031140301
# 22  -87.707371  41.840833  17031840800
# ...
